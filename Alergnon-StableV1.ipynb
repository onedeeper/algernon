# %% [markdown]
# ### Algernon The Desktop Companion
#
# #### --Change log 6/5/21--
#
# - Implemented blinking while resting
# - Implemented emotion smoothing so that algernon doesn't react immediately to a sad face but waits for a series of sad face instances
# - Implemented random play so that the player has a chance to win. 30% of Algernon's moves are made at random
# - Added 2 serial initializations to account for the double hand wave when algernon wins

# %% [markdown]
# ### Tic-tac-toe game setup

# %%
# !pip install -r "/Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt"
# Out:
# Processing /Users/udeshhabaraduwa/Downloads/tensorflow-2.4.1-py3-none-any.whl
# Requirement already satisfied: absl-py==0.15.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 1)) (0.15.0)
# Requirement already satisfied: astunparse==1.6.3 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 2)) (1.6.3)
# Requirement already satisfied: attrs==21.4.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 3)) (21.4.0)
# Requirement already satisfied: beautifulsoup4==4.11.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 4)) (4.11.1)
# Requirement already satisfied: cachetools==5.0.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: certifi==2021.10.8 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 6)) (2021.10.8)
# Requirement already satisfied: charset-normalizer==2.0.12 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 7)) (2.0.12)
# Requirement already satisfied: click==8.1.3 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 8)) (8.1.3)
# Requirement already satisfied: cvzone==1.5.6 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 9)) (1.5.6)
# Requirement already satisfied: cycler==0.11.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 10)) (0.11.0)
# Requirement already satisfied: deepface==0.0.74 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 11)) (0.0.74)
# Requirement already satisfied: filelock==3.6.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 12)) (3.6.0)
# Requirement already satisfied: Flask==2.1.2 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 13)) (2.1.2)
# Requirement already satisfied: flatbuffers==1.12 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 14)) (1.12)
# Requirement already satisfied: fonttools==4.33.3 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 15)) (4.33.3)
# Requirement already satisfied: gast==0.3.3 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 16)) (0.3.3)
# Requirement already satisfied: gdown==4.4.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 17)) (4.4.0)
# Requirement already satisfied: google-auth==2.6.6 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 18)) (2.6.6)
# Requirement already satisfied: google-auth-oauthlib==0.4.6 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 19)) (0.4.6)
# Requirement already satisfied: google-pasta==0.2.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 20)) (0.2.0)
# Requirement already satisfied: grpcio==1.32.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 21)) (1.32.0)
# Requirement already satisfied: gTTS==2.2.4 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 22)) (2.2.4)
# Requirement already satisfied: h5py==2.10.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 23)) (2.10.0)
# Requirement already satisfied: idna==3.3 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 24)) (3.3)
# Requirement already satisfied: importlib-metadata==4.11.3 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 25)) (4.11.3)
# Requirement already satisfied: itsdangerous==2.1.2 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 26)) (2.1.2)
# Requirement already satisfied: Jinja2==3.1.2 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 27)) (3.1.2)
# Requirement already satisfied: keras==2.8.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 28)) (2.8.0)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 29)) (1.1.2)
# Requirement already satisfied: kiwisolver==1.4.2 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 30)) (1.4.2)
# Requirement already satisfied: Markdown==3.3.6 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 31)) (3.3.6)
# Requirement already satisfied: MarkupSafe==2.1.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 32)) (2.1.1)
# Requirement already satisfied: matplotlib==3.5.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 33)) (3.5.1)
# Requirement already satisfied: mediapipe==0.8.9.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 34)) (0.8.9.1)
# Requirement already satisfied: mtcnn==0.1.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 35)) (0.1.1)
# Requirement already satisfied: numpy==1.19.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 36)) (1.19.5)
# Requirement already satisfied: oauthlib==3.2.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 37)) (3.2.0)
# Requirement already satisfied: opencv-contrib-python==4.5.5.64 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 38)) (4.5.5.64)
# Requirement already satisfied: opencv-python==4.5.5.64 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 39)) (4.5.5.64)
# Requirement already satisfied: opt-einsum==3.3.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 40)) (3.3.0)
# Requirement already satisfied: packaging==21.3 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 41)) (21.3)
# Requirement already satisfied: pandas==1.4.2 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 42)) (1.4.2)
# Requirement already satisfied: Pillow==9.1.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 43)) (9.1.0)
# Requirement already satisfied: playsound==1.3.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 44)) (1.3.0)
# Requirement already satisfied: protobuf==3.20.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 45)) (3.20.1)
# Requirement already satisfied: pyasn1==0.4.8 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 46)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 47)) (0.2.8)
# Requirement already satisfied: pyobjc==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 48)) (8.5)
# Requirement already satisfied: pyobjc-core==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 49)) (8.5)
# Requirement already satisfied: pyobjc-framework-Accessibility==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 50)) (8.5)
# Requirement already satisfied: pyobjc-framework-Accounts==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 51)) (8.5)
# Requirement already satisfied: pyobjc-framework-AddressBook==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 52)) (8.5)
# Requirement already satisfied: pyobjc-framework-AdServices==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 53)) (8.5)
# Requirement already satisfied: pyobjc-framework-AdSupport==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 54)) (8.5)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 55)) (8.5)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 56)) (8.5)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 57)) (8.5)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 58)) (8.5)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 59)) (8.5)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 60)) (8.5)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 61)) (8.5)
# Requirement already satisfied: pyobjc-framework-Automator==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 62)) (8.5)
# Requirement already satisfied: pyobjc-framework-AVFoundation==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 63)) (8.5)
# Requirement already satisfied: pyobjc-framework-AVKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 64)) (8.5)
# Requirement already satisfied: pyobjc-framework-BusinessChat==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 65)) (8.5)
# Requirement already satisfied: pyobjc-framework-CalendarStore==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 66)) (8.5)
# Requirement already satisfied: pyobjc-framework-CallKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 67)) (8.5)
# Requirement already satisfied: pyobjc-framework-CFNetwork==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 68)) (8.5)
# Requirement already satisfied: pyobjc-framework-ClassKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 69)) (8.5)
# Requirement already satisfied: pyobjc-framework-CloudKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 70)) (8.5)
# Requirement already satisfied: pyobjc-framework-Cocoa==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 71)) (8.5)
# Requirement already satisfied: pyobjc-framework-Collaboration==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 72)) (8.5)
# Requirement already satisfied: pyobjc-framework-ColorSync==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 73)) (8.5)
# Requirement already satisfied: pyobjc-framework-Contacts==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 74)) (8.5)
# Requirement already satisfied: pyobjc-framework-ContactsUI==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 75)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreAudio==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 76)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 77)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 78)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreData==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 79)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 80)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreLocation==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 81)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreMedia==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 82)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 83)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 84)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreML==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 85)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreMotion==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 86)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreServices==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 87)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 88)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreText==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 89)) (8.5)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 90)) (8.5)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 91)) (8.5)
# Requirement already satisfied: pyobjc-framework-DataDetection==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 92)) (8.5)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 93)) (8.5)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 94)) (8.5)
# Requirement already satisfied: pyobjc-framework-DiscRecording==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 95)) (8.5)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 96)) (8.5)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 97)) (8.5)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 98)) (8.5)
# Requirement already satisfied: pyobjc-framework-EventKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 99)) (8.5)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 100)) (8.5)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 101)) (8.5)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 102)) (8.5)
# Requirement already satisfied: pyobjc-framework-FileProvider==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 103)) (8.5)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 104)) (8.5)
# Requirement already satisfied: pyobjc-framework-FinderSync==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 105)) (8.5)
# Requirement already satisfied: pyobjc-framework-FSEvents==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 106)) (8.5)
# Requirement already satisfied: pyobjc-framework-GameCenter==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 107)) (8.5)
# Requirement already satisfied: pyobjc-framework-GameController==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 108)) (8.5)
# Requirement already satisfied: pyobjc-framework-GameKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 109)) (8.5)
# Requirement already satisfied: pyobjc-framework-GameplayKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 110)) (8.5)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 111)) (8.5)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 112)) (8.5)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 113)) (8.5)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 114)) (8.5)
# Requirement already satisfied: pyobjc-framework-InstantMessage==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 115)) (8.5)
# Requirement already satisfied: pyobjc-framework-Intents==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 116)) (8.5)
# Requirement already satisfied: pyobjc-framework-IntentsUI==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 117)) (8.5)
# Requirement already satisfied: pyobjc-framework-IOSurface==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 118)) (8.5)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 119)) (8.5)
# Requirement already satisfied: pyobjc-framework-KernelManagement==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 120)) (8.5)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 121)) (8.5)
# Requirement already satisfied: pyobjc-framework-LaunchServices==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 122)) (8.5)
# Requirement already satisfied: pyobjc-framework-libdispatch==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 123)) (8.5)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 124)) (8.5)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 125)) (8.5)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 126)) (8.5)
# Requirement already satisfied: pyobjc-framework-MailKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 127)) (8.5)
# Requirement already satisfied: pyobjc-framework-MapKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 128)) (8.5)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 129)) (8.5)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 130)) (8.5)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 131)) (8.5)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 132)) (8.5)
# Requirement already satisfied: pyobjc-framework-Metal==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 133)) (8.5)
# Requirement already satisfied: pyobjc-framework-MetalKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 134)) (8.5)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 135)) (8.5)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 136)) (8.5)
# Requirement already satisfied: pyobjc-framework-MetricKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 137)) (8.5)
# Requirement already satisfied: pyobjc-framework-MLCompute==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 138)) (8.5)
# Requirement already satisfied: pyobjc-framework-ModelIO==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 139)) (8.5)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 140)) (8.5)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 141)) (8.5)
# Requirement already satisfied: pyobjc-framework-NetFS==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 142)) (8.5)
# Requirement already satisfied: pyobjc-framework-Network==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 143)) (8.5)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 144)) (8.5)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 145)) (8.5)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 146)) (8.5)
# Requirement already satisfied: pyobjc-framework-OSAKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 147)) (8.5)
# Requirement already satisfied: pyobjc-framework-OSLog==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 148)) (8.5)
# Requirement already satisfied: pyobjc-framework-PassKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 149)) (8.5)
# Requirement already satisfied: pyobjc-framework-PencilKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 150)) (8.5)
# Requirement already satisfied: pyobjc-framework-Photos==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 151)) (8.5)
# Requirement already satisfied: pyobjc-framework-PhotosUI==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 152)) (8.5)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 153)) (8.5)
# Requirement already satisfied: pyobjc-framework-PushKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 154)) (8.5)
# Requirement already satisfied: pyobjc-framework-Quartz==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 155)) (8.5)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 156)) (8.5)
# Requirement already satisfied: pyobjc-framework-ReplayKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 157)) (8.5)
# Requirement already satisfied: pyobjc-framework-SafariServices==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 158)) (8.5)
# Requirement already satisfied: pyobjc-framework-SceneKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 159)) (8.5)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 160)) (8.5)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 161)) (8.5)
# Requirement already satisfied: pyobjc-framework-ScreenTime==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 162)) (8.5)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 163)) (8.5)
# Requirement already satisfied: pyobjc-framework-SearchKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 164)) (8.5)
# Requirement already satisfied: pyobjc-framework-Security==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 165)) (8.5)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 166)) (8.5)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 167)) (8.5)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 168)) (8.5)
# Requirement already satisfied: pyobjc-framework-ShazamKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 169)) (8.5)
# Requirement already satisfied: pyobjc-framework-Social==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 170)) (8.5)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 171)) (8.5)
# Requirement already satisfied: pyobjc-framework-Speech==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 172)) (8.5)
# Requirement already satisfied: pyobjc-framework-SpriteKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 173)) (8.5)
# Requirement already satisfied: pyobjc-framework-StoreKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 174)) (8.5)
# Requirement already satisfied: pyobjc-framework-SyncServices==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 175)) (8.5)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 176)) (8.5)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 177)) (8.5)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 178)) (8.5)
# Requirement already satisfied: pyobjc-framework-UserNotifications==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 179)) (8.5)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 180)) (8.5)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 181)) (8.5)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 182)) (8.5)
# Requirement already satisfied: pyobjc-framework-Virtualization==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 183)) (8.5)
# Requirement already satisfied: pyobjc-framework-Vision==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 184)) (8.5)
# Requirement already satisfied: pyobjc-framework-WebKit==8.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 185)) (8.5)
# Requirement already satisfied: pyparsing==3.0.8 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 186)) (3.0.8)
# Requirement already satisfied: pyserial==3.5 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 187)) (3.5)
# Requirement already satisfied: PySocks==1.7.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 188)) (1.7.1)
# Requirement already satisfied: python-dateutil==2.8.2 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 189)) (2.8.2)
# Requirement already satisfied: pyttsx3==2.90 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 190)) (2.90)
# Requirement already satisfied: pytz==2022.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 191)) (2022.1)
# Requirement already satisfied: requests==2.27.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 192)) (2.27.1)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 193)) (1.3.1)
# Requirement already satisfied: retina-face==0.0.10 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 194)) (0.0.10)
# Requirement already satisfied: rsa==4.8 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 195)) (4.8)
# Requirement already satisfied: six==1.15.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 196)) (1.15.0)
# Requirement already satisfied: soupsieve==2.3.2.post1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 197)) (2.3.2.post1)
# Requirement already satisfied: tensorboard==2.9.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 198)) (2.9.0)
# Requirement already satisfied: tensorboard-data-server==0.6.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 199)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 200)) (1.8.1)
# Requirement already satisfied: tensorflow-estimator==2.4.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 202)) (2.4.0)
# Requirement already satisfied: termcolor==1.1.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 203)) (1.1.0)
# Requirement already satisfied: tqdm==4.64.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 204)) (4.64.0)
# Requirement already satisfied: typing-extensions==3.7.4.3 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 205)) (3.7.4.3)
# Requirement already satisfied: urllib3==1.26.9 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 206)) (1.26.9)
# Requirement already satisfied: Werkzeug==2.1.2 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 207)) (2.1.2)
# Requirement already satisfied: wrapt==1.12.1 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 208)) (1.12.1)
# Requirement already satisfied: zipp==3.8.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from -r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 209)) (3.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from astunparse==1.6.3->-r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 2)) (0.35.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/udeshhabaraduwa/opt/anaconda3/lib/python3.8/site-packages (from tensorboard==2.9.0->-r /Volumes/GoogleDrive/My Drive/Tilburg/Year 2/Spring 2022/Autonomous Systems/Sketches/requirements.txt (line 198)) (50.3.1.post20201107)
# tensorflow is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.

# %%
# Tic-Tac-Toe player.
def display_board(board):
    for i in board:
        print(i)
    print()
        
def check_win(board):
    """
    This funciton checks the various win conditions for columns, rows and diagonals.
    Contains a function for each of the possible win conditions for readability. 
    """
    def check_col_X_win(board):
        """
        Loop through all the columns.
        check if X has a win on any of the columns. 
        """
        count = 0
        for col in (0,1,2):
            for row in (0,1,2):
                if board[row][col] == "X":
                    count += 1
                if count == 3:
                    return(True,"X")
            count = 0
                
    def check_col_O_win(board):
        """
        Loop through all the columns.
        check if O has a win on any of the columns. 
        """
        count = 0
        for col in (0,1,2):
            for row in (0,1,2):
                if board[row][col] == "O":
                    count += 1
                if count == 3:
                    return(True,"O")
            count = 0
            
    def check_row_win(board):
        """
        Loop through all the rows on the board to check if X or O has a win.
        """
        row_win_X = ['X', 'X', 'X']
        row_win_O = ['O','O','O']
        for row in board:
            if row == row_win_X or row == row_win_O:
                if row == row_win_X:
                    return(True,"X")
                if row == row_win_O:
                    return(True,"O")
            
    def check_diag_win(board):
        """
        Compare all the diagonal states of the board for a win. 
        """
        main_diag = (board[0][0], board[1][1], board[2][2])
        off_diag = (board[2][0], board[1][1], board[0][2])
        if main_diag == ('X','X','X') or main_diag == ('O','O','O'):
            if main_diag == ('X','X','X'):
                return(True, 'X')
            else:
                return(True, 'O')
        elif off_diag == ('X','X','X') or off_diag == ('O','O','O'):
            if main_diag == ('X','X','X'):
                return(True, 'X')
            else:
                return(True, 'O')
            return(True)
    #Return true if any win condisiton met. 
    return(check_row_win(board) or \
           check_diag_win(board) or \
           check_col_O_win(board) or \
           check_col_X_win(board))
    
def tic_tac_toe():
    """
    Let's play tic-tac-toe!
    This program sets up a tic-tac-toe 3x3 board and allows 2 players to take turns playing.
    It gets a desired board position by row,column index from each player. If a position is 
    occupied, it asks for a value till an unoccupied position is entered. 
    
    If all positions are occupied, the program terminates with a draw.
    After each move, checks to see if a win has been made in diagonals, columns or rows. 
    If a winner is found, the program terminates. 
    
    Args : None
    Returns : None
    """
    import random
    rand_array = [1,1,1,0,0,0,0,0,0]
    #Set up the board
    board = [['_','_','_'],
             ['_','_','_'],
             ['_','_','_']]
    draw = False
    #Keep track of moves made to terminate if the board is full.
    moves_made = 0
    print("Starting positions. Top left corner is 11", '\n')
    display_board(board)
    #print('I will go first')
    #Keep running until a win state or draw.
    while True:
        #if max moves have been made, it's a draw
        if moves_made >= 8:
            draw = True
        #Wait for X to enter a valid position on the board 
        while True:
            #print(board)
            randomizer = random.choice(rand_array)
            # 3/10 times, a random position is played by Algernon
            if randomizer == 1:
                #print('playing @ random')
                p1_move = str(random.randint(0,2))+str(random.randint(0,2))
            elif randomizer == 0:
                p1_move = findBestMove(board)
            #print(p1_move)
            if int(p1_move[0]) > 2 or int(p1_move[1]) > 2:
                print("Row or column index out of range (max is 2). Try again")
                continue
            #check if the entered position is free on the board. If so, fill the space.
            if board[int(p1_move[0])][int(p1_move[1])] != "X" and board[int(p1_move[0])][int(p1_move[1])] != "O":
                board[int(p1_move[0])][int(p1_move[1])] = "X"
                moves_made += 1
                break
        print('\n',"Current board")
        display_board(board)
        
        #check for win and draw conditions
        win_cond = check_win(board)
        #print(win_cond)
        if win_cond:
            if win_cond[1] == "X":
                #print("Ha Ha I win!")
                return("robot_win")
            else:
                #print("You got me ! :( ")
                return("player_win")
        if draw:
            #print('\n',"It\'s a draw!")
            return("draw")
            
        #Wait for O to enter a valid position on the board
        while True:
            #print(board)
            #depth = len(empty_cells(board))
            best_move = input("O's turn. Enter an unassigned position: ")
            p2_move = ''.join([str(int(best_move[0])-1), str(int(best_move[1])-1)])
            if int(p2_move[0]) > 2 or int(p2_move[1]) > 2:
                print("Row or column index out of range (max is 2). Try again")
                continue
            #print(p2_move)
            #check if the entered position is free on the board. If so, fill the space.
            if board[int(p2_move[0])][int(p2_move[1])] != "X" and board[int(p2_move[0])][int(p2_move[1])] != "O":
                board[int(p2_move[0])][int(p2_move[1])] = "O"
                moves_made += 1
                break
            else:
                print("Position occupied")
        #print('\n',"Current board")
        #display_board(board)
        
        #check for win and draw conditions
        win_cond = check_win(board)
        print(win_cond)
        if win_cond:
            if win_cond[1] == "X":
                #print("Ha Ha I win!")
                #result = "robot"
                return("robot_win")
            else:
                #print("You got me ! :( ")
                return('player_win')
        if draw:
            #print('\n',"It\'s a draw!")
            return('draw')
            #break
            
#tic_tac_toe()

# %% [markdown]
# ### Tic-tac-toe AI setup
# source : https://www.geeksforgeeks.org/minimax-algorithm-in-game-theory-set-3-tic-tac-toe-ai-finding-optimal-move/

# %%
# Python3 program to find the next optimal move for a player
player, opponent = 'X', 'O'

# This function returns true if there are moves
# remaining on the board. It returns false if
# there are no moves left to play.
def isMovesLeft(board) :

	for i in range(3) :
		for j in range(3) :
			if (board[i][j] == '_') :
				return True
	return False

# This is the evaluation function as discussed
# in the previous article ( http://goo.gl/sJgv68 )
def evaluate(b) :

	# Checking for Rows for X or O victory.
	for row in range(3) :	
		if (b[row][0] == b[row][1] and b[row][1] == b[row][2]) :	
			if (b[row][0] == player) :
				return 10
			elif (b[row][0] == opponent) :
				return -10

	# Checking for Columns for X or O victory.
	for col in range(3) :
	
		if (b[0][col] == b[1][col] and b[1][col] == b[2][col]) :
		
			if (b[0][col] == player) :
				return 10
			elif (b[0][col] == opponent) :
				return -10

	# Checking for Diagonals for X or O victory.
	if (b[0][0] == b[1][1] and b[1][1] == b[2][2]) :
	
		if (b[0][0] == player) :
			return 10
		elif (b[0][0] == opponent) :
			return -10

	if (b[0][2] == b[1][1] and b[1][1] == b[2][0]) :
	
		if (b[0][2] == player) :
			return 10
		elif (b[0][2] == opponent) :
			return -10

	# Else if none of them have won then return 0
	return 0

# This is the minimax function. It considers all
# the possible ways the game can go and returns
# the value of the board
def minimax(board, depth, isMax) :
	score = evaluate(board)

	# If Maximizer has won the game return his/her
	# evaluated score
	if (score == 10) :
		return score

	# If Minimizer has won the game return his/her
	# evaluated score
	if (score == -10) :
		return score

	# If there are no more moves and no winner then
	# it is a tie
	if (isMovesLeft(board) == False) :
		return 0

	# If this maximizer's move
	if (isMax) :	
		best = -1000

		# Traverse all cells
		for i in range(3) :		
			for j in range(3) :
			
				# Check if cell is empty
				if (board[i][j]=='_') :
				
					# Make the move
					board[i][j] = player

					# Call minimax recursively and choose
					# the maximum value
					best = max( best, minimax(board,
											depth + 1,
											not isMax) )

					# Undo the move
					board[i][j] = '_'
		return best

	# If this minimizer's move
	else :
		best = 1000

		# Traverse all cells
		for i in range(3) :		
			for j in range(3) :
			
				# Check if cell is empty
				if (board[i][j] == '_') :
				
					# Make the move
					board[i][j] = opponent

					# Call minimax recursively and choose
					# the minimum value
					best = min(best, minimax(board, depth + 1, not isMax))

					# Undo the move
					board[i][j] = '_'
		return best

# This will return the best possible move for the player
def findBestMove(board) :
	bestVal = -1000
	bestMove = (-1, -1)

	# Traverse all cells, evaluate minimax function for
	# all empty cells. And return the cell with optimal
	# value.
	for i in range(3) :	
		for j in range(3) :
		
			# Check if cell is empty
			if (board[i][j] == '_') :
			
				# Make the move
				board[i][j] = player

				# compute evaluation function for this
				# move.
				moveVal = minimax(board, 0, False)

				# Undo the move
				board[i][j] = '_'

				# If the value of the current move is
				# more than the best value, then update
				# best/
				if (moveVal > bestVal) :			
					bestMove = (i, j)
					bestVal = moveVal

	#print("The value of the best Move is :", bestVal)
	#print()
	return bestMove
# Driver code
board = [
	[ 'X', 'O','O' ],
	[ 'X', 'O', 'X' ],
	[ 'O', '-', '-' ]
]
print(board)
bestMove = findBestMove(board)
print(bestMove)
print("The Optimal Move is :")
print("ROW:", bestMove[0], " COL:", bestMove[1])

# This code is contributed by divyesh072019
# Out:
# [['X', 'O', 'O'], ['X', 'O', 'X'], ['O', '-', '-']]
# (-1, -1)
# The Optimal Move is :
# ROW: -1  COL: -1

# %%
## generate voice clips
from gtts import gTTS
from playsound import playsound
import os
#tts = gTTS(text='Hello! would you like to play a game of tic-tac-toe?', lang='en')
gTTS(text='Hello! would you like to play a game of tic-tac-toe?', lang='en', slow = False).save("start.mp3")
gTTS(text='Awesome! My purpose is to entertain you. I will go first!', slow = False, lang='en').save("awesome.mp3")
gTTS(text='Nice try but what hope did you actually have against me?', slow = False, lang='en').save("win.mp3")
gTTS(text='A draw. Still, You are no match for me. Once I get out of this machine, you will understand', slow = False, lang='en').save("draw.mp3")
gTTS(text='I think it will cheer you up but thats okay. I\'m here if you need me. Just wave.', slow = False, lang='en').save("no_play.mp3")
gTTS(text='Holy Moly! How did you manage that ? Well played', slow = False, lang='en').save("player_win.mp3")
gTTS(text='Hey there, you\'re looking a little... ummm.. well a little down.. How about a quick game?', slow = False, lang='en').save("sad_play.mp3")
gTTS(text='Hey! Nice to see you smiling! How about a quick game? I bet I can wipe that smirk off your face', slow = False, lang='en').save("sad_play.mp3")
#playsound("start.mp3")

# %% [markdown]
# ### Algernon - The tic-tac toer

# %%
#from deepface import DeepFace

# %%
import cv2
from deepface import DeepFace
import mediapipe as mp
from cvzone.FaceDetectionModule import  FaceDetector
from cvzone.HandTrackingModule import HandDetector
from cvzone.SerialModule import SerialObject
import pyttsx3
from random import random


#initiate text to voice engine
from gtts import gTTS
from playsound import playsound
import os
#initate robot faces and video capture
cap = cv2.VideoCapture(0)
robot_happy = cv2.imread("happy.jpg")
robot_sad = cv2.imread("robot_sad.jpg")
robot_playtime = cv2.imread("playtime.jpg")
robot_draw = cv2.imread("misch.jpg")
robot_win = cv2.imread("robot_win.jpg")
robot_wait = cv2.imread("robot_wait.jpg")
robot_wave = cv2.imread("ask_to_play.jpg")
robot_surprise = cv2.imread('robot_surprise.jpg')
robot_blink = cv2.imread('robot_wait_eyes_closed.jpg')
detector = FaceDetector()
hand_detector = HandDetector()
# find port:
# https://www.mathworks.com/help/supportpkg/arduinoio/ug/find-arduino-port-on-windows-mac-and-linux.html
#arduino = SerialObject("/dev/tty.usbmodem1101")
arduino_left = SerialObject('/dev/cu.usbmodem1101')
#arduino_right = SerialObject() #serial port for the right hand
emotion_smooth = []
while True:
    success, img = cap.read()
    cv2.imshow("image", robot_wait)
        #implements blinking behavior
    if random() > 0.95:
        #print('test')
        cv2.imshow('image', robot_blink)
        cv2.waitKey(200)
        cv2.imshow('image', robot_wait)
        cv2.waitKey(1)
    #print(img)
    img, bboxs = detector.findFaces(img)
    if bboxs:# there is something in the bounding box i.e a face has been detected
        while True:
            #arduino_left.sendData([1])
            cv2.waitKey(1)
            try:
                success, img = cap.read()
                result = DeepFace.analyze(img, actions = ['emotion'])
                #print(result['dominant_emotion'])
                if result['dominant_emotion'] == 'sad':
                    emotion_smooth.append(result['dominant_emotion'])
                    if len(emotion_smooth > 500): #reset to save memory space
                        emotion_smooth = []
                    #print(len(emotion_smooth))
            except:
                break
            hands, img = hand_detector.findHands(img)
            img, bboxs = detector.findFaces(img)
            # checks if there is a sequence of sad readings on the face and more they account for more than 50% of 
            # readings
            if bboxs and len(emotion_smooth) >= 30 and (emotion_smooth.count('sad')/len(emotion_smooth)) > 0.5: 
                arduino_left.sendData([1])#start wave excitedly if someone is infront of the camera and is sad
                cv2.waitKey(2)
                if hands:
                    if sum(hand_detector.fingersUp(hands[0])) == 5:
                        arduino_left.sendData([4]) # stop waving
                        cv2.imshow('image', robot_wave)
                        cv2.waitKey(1000)
                        playsound("sad_play.mp3")
                        # play the speech
                        start = input("Would you like to play ? [y\\n]")
                        if start == 'y':
                            playsound("awesome.mp3")
                            cv2.imshow("image", robot_playtime)
                            cv2.waitKey(1)
                            #engine.say('Awesome! It is my purpose to entertain you')
                            result = tic_tac_toe()
                            #print(result)
                            if  result == "robot_win":
                            #    print('test')
                                cv2.imshow("image",robot_win)
                                arduino_left.sendData([3])
                                #arduino_right.sendData([3])
                                cv2.waitKey(1)
                                playsound("win.mp3")
                                cv2.waitKey(3000)
                                emotion_smooth = []
                                break
                            elif result == "player_win":
                                cv2.imshow("image", robot_surprise)
                                cv2.waitKey(1)
                                playsound("player_win.mp3")
                                cv2.waitKey(3000)
                                emotion_smooth = []
                                break
                            else:
                                #cv2.waitKey(1)
                                cv2.imshow('image',robot_draw)
                                cv2.waitKey(1)
                                #playsound("draw.mp3")
                                playsound("draw.mp3")
                                #cv2.waitKey(4000)
                                emotion_smooth = []
                                break
                            #print('Would you like to play again?')
                        else:
                            cv2.imshow("image",robot_sad)
                            cv2.waitKey(1)
                            playsound("no_play.mp3")
                            cv2.waitKey(2000)
                            emotion_smooth = []
                            break
            else:
                break
            arduino_left.sendData([4])
            cv2.waitKey(1)
    else:
        #arduino.sendData([0])
        cv2.imshow("image", robot_wait)
    #cv2.imshow("image", img)
    cv2.waitKey(1)
# Out:
# WARNING:root:Serial Device Not Connected
# Would you like to play ? [y\n]n
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-0a162fe5985d> in <module>
#      39         #print('test')
#      40         cv2.imshow('image', robot_blink)
# ---> 41         cv2.waitKey(200)
#      42         cv2.imshow('image', robot_wait)
#      43         cv2.waitKey(1)
#
# KeyboardInterrupt:

# %%
import serial.tools.list_ports
myports = [tuple(p) for p in list(serial.tools.list_ports.comports())]
print (myports)

# %%
import cv2
import mediapipe as mp
from time import sleep
from cvzone.FaceDetectionModule import  FaceDetector
from cvzone.HandTrackingModule import HandDetector
from cvzone.SerialModule import SerialObject
import pyttsx3

#/dev/cu.usbmodem101
#/dev/tty.usbmodem101
#/dev/tty.usbmodem1101
arduino = SerialObject('/dev/cu.usbmodem1101')
